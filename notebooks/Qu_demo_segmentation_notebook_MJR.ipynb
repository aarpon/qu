# %% [markdown]
# # Qu: demo segmentation notebook

# %% [markdown]
# ## Set up and import

# %%
# Import relevant modules
from pathlib import Path

import matplotlib.pyplot as plt
from tifffile import imread
import torch
import sys
sys.path.append("..")
# %config Completer.use_jedi = False
from qu.data import DataManager
from qu.models import UNet2DSegmenter
from qu.models import UNet2DSegmenterSettings
from qu.demo import get_demo_segmentation_dataset

# %% [markdown]
# ## Prepare the data and the model

# %%
# Get the demo dataset
data_root_path = get_demo_segmentation_dataset()
print(data_root_path)

# Set the working dir
working_dir = data_root_path
# Out:
# /home/matt/.qu/data/demo_segmentation

# %%
# Notice: you can point tensorboard to ${data_root_path}.

# %%
# Scan for data
dataManager = DataManager()
dataManager.root_data_path = data_root_path
dataManager.scan()
# Out:
# True

# %%
# Report on the experiment type
print(f"Experiment type = {dataManager.experiment_type}")
# Out:
# Experiment type = ExperimentType.CLASSIFICATION

# %%
# Summary of found data
print(f"Found {dataManager.num_images} images.")
print(f"Found {dataManager.num_masks} masks.")
print(f"Found {dataManager.num_targets} targets (expected 0).")
# Out:
# Found 90 images.
# Found 90 masks.
# Found 0 targets (expected 0).

# %%
# Split images into training, validation and test set
train_image_names, train_mask_names, \
val_image_names, val_mask_names, \
test_image_names, test_mask_names = dataManager.training_split()

# %%
# Report split
print(f"Split: {len(train_image_names)}/{len(val_image_names)}/{len(test_image_names)}")
# Out:
# Split: 67/18/5

# %%
# Show an example pair
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2,figsize=(15,10))
ax1.imshow(imread(train_image_names[0]), cmap='gray')
ax1.set_title("Image")
ax2.imshow(imread(train_mask_names[0]), cmap='gray')
ax2.set_title("Mask (ground truth)")
ax2.set_xlabel("0 = background, 1 = cell, 2 = border")
# Out:
# Text(0.5, 0, '0 = background, 1 = cell, 2 = border')

# %% [markdown]
# ## Set up the Segmenter

# %%
# Check
print(f"Number of input channels found in image data: {dataManager.num_input_channels}")
print(f"Number of classes found in mask data: {dataManager.num_classes}")
print(f"Mask type estimated from mask data: {dataManager.mask_type}")
# Out:
# Number of input channels found in image data: 1
# Number of classes found in mask data: 3
# Mask type estimated from mask data: MaskType.TIFF_LABELS

# %%
# Initialize the settings
settings = UNet2DSegmenterSettings()

# %%
# Change some settings from their default values
settings.roi_size = (512, 512)
settings.batch_sizes = (8, 1, 1, 1)
#settings.num_epochs = 10

# %%
# Get the settings as dictionary
settings_dict = settings.to_dict()

# %%
# Initialize the Segmenter passing the settings dictionary
segmenter = UNet2DSegmenter(
    in_channels=dataManager.num_input_channels,
    out_channels=dataManager.num_classes,
    # **settings_dict,
    num_epochs=10,
    working_dir=working_dir
)

# %%
# Add the data
segmenter.set_training_data(
    train_image_names,
    train_mask_names,
    val_image_names,
    val_mask_names,
    test_image_names,
    test_mask_names
)

# %% [markdown]
# ## Train the model

# %%
# Free GPU memory
torch.cuda.empty_cache()

# %%
# Train the model
result = segmenter.train()
# Out:
# Using device 'cpu'.
# --------------------------------------------------------------------------------
# Epoch 1/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.8751
# Batch 2/9: train_loss = 0.8236
# Batch 3/9: train_loss = 0.8828
# Batch 4/9: train_loss = 0.8836
# Batch 5/9: train_loss = 0.8506
# Batch 6/9: train_loss = 0.8284
# Batch 7/9: train_loss = 0.8048
# Batch 8/9: train_loss = 0.8109
# Batch 9/9: train_loss = 0.8694
# Average loss = 0.8477
# --------------------------------------------------------------------------------
# Epoch 2/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.7990
# Batch 2/9: train_loss = 0.8319
# Batch 3/9: train_loss = 0.8475
# Batch 4/9: train_loss = 0.8979
# Batch 5/9: train_loss = 0.7738
# Batch 6/9: train_loss = 0.8424
# Batch 7/9: train_loss = 0.8090
# Batch 8/9: train_loss = 0.7817
# Batch 9/9: train_loss = 0.8345
# Average loss = 0.8242
# --------------------------------------------------------------------------------
# Validation
# --------------------------------------------------------------------------------
# Global metric = 0.5583
# Class 'Background' metric = 0.5541
# Class 'Object' metric = 0.7243
# Class 'Border' metric = 0.3964
# New best global metric = 0.5583 at epoch: 2
# Saved best model 'best_model_20210127_160535.pth'
# --------------------------------------------------------------------------------
# Epoch 3/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.7669
# Batch 2/9: train_loss = 0.7426
# Batch 3/9: train_loss = 0.8602
# Batch 4/9: train_loss = 0.8631
# Batch 5/9: train_loss = 0.8098
# Batch 6/9: train_loss = 0.7433
# Batch 7/9: train_loss = 0.7591
# Batch 8/9: train_loss = 0.7830
# Batch 9/9: train_loss = 0.7468
# Average loss = 0.7861
# --------------------------------------------------------------------------------
# Epoch 4/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.7417
# Batch 2/9: train_loss = 0.7287
# Batch 3/9: train_loss = 0.8506
# Batch 4/9: train_loss = 0.8586
# Batch 5/9: train_loss = 0.7973
# Batch 6/9: train_loss = 0.7330
# Batch 7/9: train_loss = 0.7444
# Batch 8/9: train_loss = 0.7439
# Batch 9/9: train_loss = 0.7821
# Average loss = 0.7756
# --------------------------------------------------------------------------------
# Validation
# --------------------------------------------------------------------------------
# Global metric = 0.7193
# Class 'Background' metric = 0.7482
# Class 'Object' metric = 0.8331
# Class 'Border' metric = 0.5766
# New best global metric = 0.7193 at epoch: 4
# Saved best model 'best_model_20210127_160535.pth'
# --------------------------------------------------------------------------------
# Epoch 5/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.7117
# Batch 2/9: train_loss = 0.7101
# Batch 3/9: train_loss = 0.7589
# Batch 4/9: train_loss = 0.7795
# Batch 5/9: train_loss = 0.7594
# Batch 6/9: train_loss = 0.7169
# Batch 7/9: train_loss = 0.7219
# Batch 8/9: train_loss = 0.7184
# Batch 9/9: train_loss = 0.6781
# Average loss = 0.7283
# --------------------------------------------------------------------------------
# Epoch 6/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.6404
# Batch 2/9: train_loss = 0.7127
# Batch 3/9: train_loss = 0.7414
# Batch 4/9: train_loss = 0.7417
# Batch 5/9: train_loss = 0.6878
# Batch 6/9: train_loss = 0.7030
# Batch 7/9: train_loss = 0.6731
# Batch 8/9: train_loss = 0.7159
# Batch 9/9: train_loss = 0.6994
# Average loss = 0.7017
# --------------------------------------------------------------------------------
# Validation
# --------------------------------------------------------------------------------
# Global metric = 0.7822
# Class 'Background' metric = 0.8885
# Class 'Object' metric = 0.8675
# Class 'Border' metric = 0.5907
# New best global metric = 0.7822 at epoch: 6
# Saved best model 'best_model_20210127_160535.pth'
# --------------------------------------------------------------------------------
# Epoch 7/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.6178
# Batch 2/9: train_loss = 0.6939
# Batch 3/9: train_loss = 0.7577
# Batch 4/9: train_loss = 0.7634
# Batch 5/9: train_loss = 0.6774
# Batch 6/9: train_loss = 0.6058
# Batch 7/9: train_loss = 0.6562
# Batch 8/9: train_loss = 0.6315
# Batch 9/9: train_loss = 0.6552
# Average loss = 0.6732
# --------------------------------------------------------------------------------
# Epoch 8/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.6222
# Batch 2/9: train_loss = 0.6266
# Batch 3/9: train_loss = 0.6996
# Batch 4/9: train_loss = 0.8108
# Batch 5/9: train_loss = 0.6706
# Batch 6/9: train_loss = 0.6596
# Batch 7/9: train_loss = 0.6746
# Batch 8/9: train_loss = 0.6253
# Batch 9/9: train_loss = 0.6588
# Average loss = 0.6720
# --------------------------------------------------------------------------------
# Validation
# --------------------------------------------------------------------------------
# Global metric = 0.8567
# Class 'Background' metric = 0.9665
# Class 'Object' metric = 0.9370
# Class 'Border' metric = 0.6665
# New best global metric = 0.8567 at epoch: 8
# Saved best model 'best_model_20210127_160535.pth'
# --------------------------------------------------------------------------------
# Epoch 9/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.5997
# Batch 2/9: train_loss = 0.5958
# Batch 3/9: train_loss = 0.7568
# Batch 4/9: train_loss = 0.7369
# Batch 5/9: train_loss = 0.6549
# Batch 6/9: train_loss = 0.6227
# Batch 7/9: train_loss = 0.6141
# Batch 8/9: train_loss = 0.6133
# Batch 9/9: train_loss = 0.6459
# Average loss = 0.6489
# --------------------------------------------------------------------------------
# Epoch 10/10
# --------------------------------------------------------------------------------
# Batch 1/9: train_loss = 0.6060
# Batch 2/9: train_loss = 0.6191
# Batch 3/9: train_loss = 0.7444
# Batch 4/9: train_loss = 0.6904
# Batch 5/9: train_loss = 0.6155
# Batch 6/9: train_loss = 0.5803
# Batch 7/9: train_loss = 0.5312
# Batch 8/9: train_loss = 0.6261
# Batch 9/9: train_loss = 0.5695
# Average loss = 0.6203
# --------------------------------------------------------------------------------
# Validation
# --------------------------------------------------------------------------------
# Global metric = 0.8695
# Class 'Background' metric = 0.9754
# Class 'Object' metric = 0.9357
# Class 'Border' metric = 0.6974
# New best global metric = 0.8695 at epoch: 10
# Saved best model 'best_model_20210127_160535.pth'
# Training completed. Best_metric = 0.8695 at epoch: 10

# %%
if not result:
    print(segmenter.get_message())

# %% [markdown]
# ## Test predict

# %%
# Run prediction on the test set
result = segmenter.test_predict()
# Out:
# --------------------------------------------------------------------------------
# Test prediction
# --------------------------------------------------------------------------------
# Loaded best metric model /home/matt/.qu/data/demo_segmentation/runs/best_model_20210127_160535.pth.
# Saved /home/matt/.qu/data/demo_segmentation/tests/pred_t077.tif
# Saved /home/matt/.qu/data/demo_segmentation/tests/pred_t042.tif
# Saved /home/matt/.qu/data/demo_segmentation/tests/pred_t022.tif
# Saved /home/matt/.qu/data/demo_segmentation/tests/pred_t006.tif
# Saved /home/matt/.qu/data/demo_segmentation/tests/pred_t061.tif
# Test prediction completed.

# %%
if not result:
    print(segmenter.get_message())

# %%
# Load one of the predicted images for comparison
filename = Path(test_image_names[0]).name.replace('train_', 'pred_')
filename = data_root_path / "tests" / filename
prediction = imread(filename)

# %%
# Show an example test prediction
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(15,10))
ax1.imshow(imread(test_mask_names[0]), cmap='gray')
ax1.set_title("Mask (ground truth)")
ax1.set_xlabel("0 = background, 1 = cell, 2 = border")
ax2.imshow(prediction, cmap='gray')
ax2.set_title("Prediction")
ax2.set_xlabel("0 = background, 1 = cell, 2 = border")
# Out:
# Text(0.5, 0, '0 = background, 1 = cell, 2 = border')

# %% [markdown]
# ## Predict on new data

# %%
# Get path of best model
best_model_path = segmenter.get_best_model_path()
print(best_model_path)
# Out:
# /home/matt/.qu/data/demo_segmentation/runs/best_model_20210127_160535.pth

# %%
# Just for the sake of example, predict on all images. 
# In practice, you would use brand new images here.
input_folder = Path(data_root_path) / "images"
output_folder = Path(working_dir) / "preds"

result = segmenter.predict(input_folder, output_folder, best_model_path)
# Out:
# --------------------------------------------------------------------------------
# Prediction
# --------------------------------------------------------------------------------
# Loaded best metric model /home/matt/.qu/data/demo_segmentation/runs/best_model_20210127_160535.pth.
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t000.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t001.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t002.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t003.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t004.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t005.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t006.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t007.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t008.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t009.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t010.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t011.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t012.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t013.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t014.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t015.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t016.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t017.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t018.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t019.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t020.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t021.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t022.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t023.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t024.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t025.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t026.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t027.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t028.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t029.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t030.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t031.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t032.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t033.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t034.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t035.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t036.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t037.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t038.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t039.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t040.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t041.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t042.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t043.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t044.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t045.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t046.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t047.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t048.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t049.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t050.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t051.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t052.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t053.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t054.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t055.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t056.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t057.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t058.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t059.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t060.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t061.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t062.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t063.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t064.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t065.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t066.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t067.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t068.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t069.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t070.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t071.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t072.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t073.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t074.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t075.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t076.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t077.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t078.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t079.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t080.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t081.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t082.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t083.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t084.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t085.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t086.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t087.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t088.tif
# Saved /home/matt/.qu/data/demo_segmentation/preds/pred_train_t089.tif
# Prediction completed.

# %%
if not result:
    print(segmenter.get_message())

# %% [markdown]
# ## Evaluating results visually

# %%
from skimage.metrics import structural_similarity as ssim
from PIL import Image
import numpy as np 

def compare_images(truth_img_path, pred_img_path):
    # import images
    if isinstance(truth_img_path, Path):
        truth_img_path = str(truth_img_path.resolve())
    if isinstance(pred_img_path, Path):
        pred_img_path = str(pred_img_path.resolve())
    truth_img = np.array(Image.open(truth_img_path))
    pred_img = np.array(Image.open(pred_img_path))
    # display differences
    truth_img = np.array(Image.open(truth_img_path))
     # difference in all classes
    gen_diff = truth_img != pred_img
    
    # difference for each classes
    class_list = list(np.unique(truth_img))[1:]
    print(class_list)
    fig,axs = plt.subplots(ncols=1, nrows=class_list[-1]+1, figsize=(30,35))
    for a,n in enumerate(class_list):
        t_im = truth_img.copy()
        t_im[ t_im != n ] = 0
        p_im = pred_img.copy()
        p_im[ p_im != n ] = 0
        
        axs[a].imshow(p_im != t_im)
        axs[a].set_title(f" difference in class {n}" )
        axs[a].set_axis_off()
    axs[class_list[-1]].imshow(gen_diff)
    axs[class_list[-1]].set_title("overall difference")
    axs[class_list[-1]].set_axis_off()
    pass

# %%
true_mask = input_folder.parent / "masks" / "mask_t000.tif"
pred_mask = output_folder / "pred_train_t000.tif"
compare_images(true_mask, pred_mask)
# Out:
# [1, 2]

# %%
true_mask = input_folder.parent / "masks" / "mask_t002.tif"
pred_mask = output_folder / "pred_train_t002.tif"
compare_images(true_mask, pred_mask)
# Out:
# [1, 2]

# %%
true_mask = input_folder.parent / "masks" / "mask_t005.tif"
pred_mask = output_folder / "pred_train_t005.tif"
compare_images(true_mask, pred_mask)
# Out:
# [1, 2]

# %%
true_mask = input_folder.parent / "masks" / "mask_t010.tif"
pred_mask = output_folder / "pred_train_t010.tif"
compare_images(true_mask, pred_mask)
# Out:
# [1, 2]
